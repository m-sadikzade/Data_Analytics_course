# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = pd.read_csv('conversion.csv')
data
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# ...

# %%
data.dtypes
# Out:
# ad_id                    int64
# xyz_campaign_id          int64
# fb_campaign_id           int64
# age                     object
# gender                  object
# interest                 int64
# Impressions              int64
# Clicks                   int64
# Spent                  float64
# Total_Conversion         int64
# Approved_Conversion      int64
# dtype: object

# %%
data.isna().sum()
# Out:
# ad_id                  0
# xyz_campaign_id        0
# fb_campaign_id         0
# age                    0
# gender                 0
# interest               0
# Impressions            0
# Clicks                 0
# Spent                  0
# Total_Conversion       0
# Approved_Conversion    0
# dtype: int64

# %%
for clmn in data.columns:
    print(clmn+':', data[clmn].unique())
# Out:
# ad_id: [ 708746  708749  708771 ... 1314412 1314414 1314415]
# xyz_campaign_id: [ 916  936 1178]
# fb_campaign_id: [103916 103917 103920 103928 103929 103940 103941 103951 103952 103955
#  103962 103965 103968 103976 103978 103979 103988 103989 104012 104013
#  104034 104049 104061 104085 104108 104109 104133 104140 104185 104205
#  104220 104228 104229 104230 104239 104252 104265 104270 104272 104285
#  104287 104328 104396 104419 104423 104438 104467 108654 108655 108660
#  108664 108665 108668 108672 108678 108680 108683 108686 108689 108690
#  108691 108692 108716 108720 108729 108730 108740 108742 108750 108752
#  108753 108761 108762 108764 108766 108770 108774 108776 108781 108786
#  108788 108791 108792 108793 108794 108797 108804 108809 108810 108811
#  108817 108818 108822 108823 108826 108827 108834 108836 109448 109451
#  109452 109470 109472 109473 109498 109507 109553 109565 109601 109629
#  109633 109637 109659 109689 109698 109706 109714 109717 109731 109738
# ...

# %%
data.xyz_campaign_id.nunique()
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %%
data.dtypes
# Out:
# ad_id                    int64
# xyz_campaign_id          int64
# fb_campaign_id           int64
# age                     object
# gender                  object
# interest                 int64
# Impressions              int64
# Clicks                   int64
# Spent                  float64
# Total_Conversion         int64
# Approved_Conversion      int64
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
res = data.groupby('fb_campaign_id').agg({'Impressions':'sum'})
np.log(res)
# Out:
#                 Impressions
# fb_campaign_id
# 103916             8.902456
# 103917             9.790375
# 103920             6.541030
# 103928             9.035034
# 103929             7.557473
# ...                     ...
# 179977            13.937527
# 179978            13.365386
# 179979            11.928546
# 179981            13.580108
# 179982            13.148345
#
# [691 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(30, 8))
sns.barplot(data=np.log(res).reset_index(), x='fb_campaign_id', y='Impressions')
# Out:
# <AxesSubplot:xlabel='fb_campaign_id', ylabel='Impressions'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %%
data['CTR'] = data.Clicks/data.Impressions

# %%
data.CTR.describe()
# Out:
# count    1143.000000
# mean        0.000164
# std         0.000115
# min         0.000000
# 25%         0.000100
# 50%         0.000160
# 75%         0.000234
# max         0.001059
# Name: CTR, dtype: float64

# %%
data.query("CTR >= 0.001059")
# Out:
#       ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 150  738637              936          109857  45-49      F        24
#
#      Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 150          944       1   1.42                 1                    0
#
#           CTR
# 150  0.001059

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion       CTR
# 0         7350       1   1.43                 2                    1  0.000136
# 1        17861       2   1.82                 2                    0  0.000112
# 2          693       0   0.00                 1                    0  0.000000
# 3         4259       1   1.25                 1                    0  0.000235
# 4         4133       1   1.29                 1                    1  0.000242

# %%
camaigns = data.xyz_campaign_id.unique()

# %%
for i, cp in enumerate(camaigns):
    res = data.query('xyz_campaign_id == @cp')
    plt.figure(i)
    ax = sns.distplot(res['CTR'], bins=20)
    ax.set_title(f'{cp}')
# Out:
# c:\users\elnur\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   after removing the cwd from sys.path.
# c:\users\elnur\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion       CTR
# 0         7350       1   1.43                 2                    1  0.000136
# 1        17861       2   1.82                 2                    0  0.000112
# 2          693       0   0.00                 1                    0  0.000000
# 3         4259       1   1.25                 1                    0  0.000235
# 4         4133       1   1.29                 1                    1  0.000242

# %%
data['CPC'] = data.Spent/data.Clicks

# %%
data = data.dropna()

# %%
data
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# 6      708889              916          103940  30-34      M        15
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# ...

# %%
import scipy as sp

# %%
for i, cp in enumerate(camaigns):
    res = data.query('xyz_campaign_id == @cp')
    plt.figure(i)
    ax = sns.distplot(res['CPC'], bins=20)
    ax.set_title(f'{cp}')
# Out:
# c:\users\elnur\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   after removing the cwd from sys.path.
# c:\users\elnur\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...
