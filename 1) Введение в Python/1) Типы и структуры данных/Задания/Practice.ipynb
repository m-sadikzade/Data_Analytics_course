# %% [markdown]
# ![image.png](attachment:b041b906-9658-4b35-81a2-c14f7f707342.png)

# %%
name = 'Мирахмад'
age = 18

# %% [markdown]
# ![image.png](attachment:83f67e71-929e-4ce0-9eae-c87c9e635efb.png)

# %%
age_days = age*365

# %% [markdown]
# ![image.png](attachment:3c4d709c-415a-4b1d-b3a4-a948a6033121.png)

# %%
temperature_day1 = 36.7
#float

# %% [markdown]
# ![image.png](attachment:8f337ce5-ff22-441b-bb0c-d75ed1209bb6.png)

# %%
temperature_is_ok = 36.6
temperature_is_ok = (temperature_day1 == temperature_is_ok)
temperature_is_ok
# Out:
# False

# %% [markdown]
# ![image.png](attachment:418c160d-6cd0-48ec-9417-182874178939.png)

# %%
day1 = name +', '+ str(age) + ' лет' +', '+ 'температура ' + str(temperature_day1)
day1
# Out:
# 'Мирахмад, 18 лет, температура 36.7'

# %% [markdown]
# ![image.png](attachment:cc29bf53-0787-4dd9-91fd-8d5d3e6665a1.png)

# %%
day1 = f'{name}, {age} лет, температура {temperature_day1}'
print(day1)
# Out:
# Мирахмад, 18 лет, температура 36.7

# %% [markdown]
# ![image.png](attachment:4e6b414c-02cb-45a1-be74-b4d8a7b5ecab.png)

# %%
my_temperatures = [temperature_day1]
temperature_day2 = 36.6
my_temperatures.append(temperature_day2)

# %% [markdown]
# ![image.png](attachment:8e9376da-2434-4a6d-ae01-4f5ac39a0eac.png)

# %%
days = ['01.02', '02.02', '04.02']
days.pop(-1)
days.append('03.02')

# %%
days
# Out:
# ['01.02', '02.02', '03.02']

# %%
days = ['01.02', '02.02', '04.02']
days[-1] = '03.02'

# %%
days
# Out:
# ['01.02', '02.02', '03.02']

# %% [markdown]
# ![image.png](attachment:051e3e55-0621-454d-8661-5482c1dbb080.png)

# %%
many_temperatures = [36.7, 36.6, 36.4, 36.9, 36.6]

# %%
avg_temperature = sum(many_temperatures)/len(many_temperatures)
avg_temperature
# Out:
# 36.64

# %% [markdown]
# ![image.png](attachment:b9778888-cb14-4a11-b2af-fbf4227cc681.png)

# %%
normal_range = (36.0, 37.0)

# %%
lower_bound = normal_range[0]
upper_bound = normal_range[1]

# %% [markdown]
# ![image.png](attachment:bf31084c-c29e-4627-b16e-afad6a1ea5d1.png)

# %%
result = lower_bound <= avg_temperature <= upper_bound

# %%
result
# Out:
# True

# %% [markdown]
# ![image.png](attachment:56965c44-5c6f-421f-8ec2-8fe520753031.png)

# %% [markdown]
# ![image.png](attachment:26ffe7e8-9d57-45f3-b6f5-99b0f6c3fe4d.png)

# %%
message = '  Через тернии к звёздам_'

# %%
fixed_message = message[0:-1]+'!'
fixed_message = ' '.join(fixed_message.split())
# Out:
# 'Через тернии к звёздам!'

# %% [markdown]
# ![image.png](attachment:c3259c8b-9ec6-40b4-af0f-d570897253fe.png)

# %%
my_message = 'Через тернии к звёздам!'

# %%
reversed_message = my_message[::-1]
reversed_message
# Out:
# '!мадзёвз к иинрет зереЧ'

# %% [markdown]
# ![image.png](attachment:2fb9672a-e3c9-41cd-8f81-58447a36871e.png)

# %%
fruits = 'банан, грейпфрут, апельсин, киви, груша, манго, лимон, молоко, сыр, овсянка'

# %%
fruits_list = fruits.split(', ')[:7]

# %% [markdown]
# ![image.png](attachment:2bb5970e-c1eb-4e3d-a70c-cd2ab56d47fc.png)

# %%
fruits_list = ['банан', 'грейпфрут', 'апельсин', 'киви', 'груша', 'манго', 'лимон']

# %%
fruits_list.remove('манго')
fruits_list.insert(0, 'яблоко')
fruits_list
# Out:
# ['яблоко', 'банан', 'грейпфрут', 'апельсин', 'киви', 'груша', 'лимон']

# %% [markdown]
# ![image.png](attachment:6e618f9e-f43b-450b-81ba-a7235147514d.png)

# %%
fruits_list = ['яблоко', 'банан', 'грейпфрут', 'апельсин', 'киви', 'груша', 'лимон']

# %%
my_fruits_list = fruits_list[1::2]
my_fruits_list
# Out:
# ['банан', 'апельсин', 'груша']

# %% [markdown]
# ![image.png](attachment:7be0047f-f9cf-4d71-b0d5-c9f5a75d7055.png)

# %%
friend_products_set = {'черника', 'клубника', 'малина', 'апельсин', 'гранат', 'банан'}

# %%
my_products_set = set(my_fruits_list)
my_products_set.update(friend_products_set)

# %%
my_products_set
# Out:
# {'апельсин', 'банан', 'гранат', 'груша', 'клубника', 'малина', 'черника'}

# %% [markdown]
# ![image.png](attachment:6eae3763-0597-4b2b-8f6d-ef5422d7ad55.png)

# %%
user_dict = {
    'name'   : 'Иван',
    'surname': 'Крылов',
    'age'    : 25,
    'grade'  : 'junior'
}

# %% [markdown]
# ![image.png](attachment:46100064-630b-4201-9f31-8614c27f15bf.png)

# %%
user_dict['salary'] = 60000

# %% [markdown]
# ![image.png](attachment:c10fc06c-61b1-4a5e-8870-3c3ebc5e8c9c.png)

# %%
users_dict = {
    'ikrilov': {'name':'Иван', 'surname':'Крылов', 'age':25, 'grade':'junior', 'salary':60000},
    'mvolkova': {'name':'Мария', 'surname':'Волкова', 'age':29, 'grade':'senior', 'salary':250000},
    'pparker': {'name':'Питер', 'surname':'Паркер', 'age':27, 'grade':'middle', 'salary':150000}
}

# %% [markdown]
# ![image.png](attachment:fd0a719f-dbff-49fc-a315-56d1bde095cf.png)

# %%
ds_dict = {
    'skills': ['SQL', 'Статистика', 'Визуализация', 'Git', 'ML'],
    'qualities': ['Python', 'Энтузиазм', 'Любознательность']
    }

# %%
ds_dict['qualities'].remove('Python')
ds_dict['skills'].insert(0, 'Python')
ds_dict['qualities'].append('Внимательность')
ds_dict['hobbies'] = ['Чтение', 'Настольные игры', 'Спорт', 'Иностранные языки']

# %% [markdown]
# ![image.png](attachment:31f8ed79-89a1-4360-8ac4-ced79ed0c184.png)

# %%
minutes_range = [min for min in range(120, 241, 5)]
minutes_range = list(range(120, 241, 5))

# %% [markdown]
# ![image.png](attachment:513575b8-93a2-479d-9243-48483c7eb03f.png)

# %%
print(f'Всего дней: {len(minutes_range)}, всего минут: {sum(minutes_range)}, в среднем минут в день: {sum(minutes_range)//len(minutes_range)}')
# Out:
# Всего дней: 25, всего минут: 4500, в среднем минут в день: 180
