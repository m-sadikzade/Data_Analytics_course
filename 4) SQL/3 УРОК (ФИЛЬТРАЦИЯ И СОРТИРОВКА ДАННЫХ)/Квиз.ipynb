# %% [markdown]
# ![image.png](attachment:4d3756f6-0b07-4501-946c-f74feb4e3f62.png)

# %% [markdown]
# ![image.png](attachment:fb2b7474-fa36-431c-873d-840f4972299f.png)

# %% [markdown]
# ![image.png](attachment:7c0622f1-ed1a-45b5-90dd-272284bcf7f5.png)

# %% [markdown]
# ![image.png](attachment:c5f7a6ba-ccae-4dc0-afe9-1d937250e8d8.png)

# %% [markdown]
# ![image.png](attachment:1b12bbd9-78ce-450e-9cae-4690797c6d2a.png)

# %% [markdown]
# ![image.png](attachment:c5e33f05-dbcf-4222-ba0f-78f7c3c37fdd.png)

# %% [markdown]
# ![image.png](attachment:0689369c-10c1-4cd1-b515-7132c6fe7581.png)
# ![image.png](attachment:1e5604eb-f3e6-46e1-a266-44b43fbadf7e.png)

# %% [markdown]
# ![image.png](attachment:ce4cf1ff-52ec-43ef-bd15-f67d1632bc3c.png)

# %% [markdown]
# ![image.png](attachment:8c93a079-6790-446c-b22a-2dd643f51948.png)

# %% [markdown]
# ![image.png](attachment:5dae125c-bd4d-4b48-9d45-a232fee59177.png)

# %% [markdown]
# ![image.png](attachment:c97bfdc3-8430-4742-bcb0-816f1bdcef24.png)

# %% [markdown]
# ![image.png](attachment:99bc7863-bd6d-4148-ad1a-582820b2335f.png)

# %% [markdown]
# ![image.png](attachment:dbf79b72-8dcb-4ae2-aa82-c371b01e8cc9.png)

# %% [markdown]
# ![image.png](attachment:25564909-0d18-4236-9ab2-b7e219b420ed.png)
