# %% [markdown]
# ![image.png](attachment:d313b794-a7c9-437f-b841-b475fc430bf1.png)
# ![image.png](attachment:af7ddd30-4c00-4458-9f41-7ca8f1f6e69c.png)

# %% [markdown]
# ![image.png](attachment:008653fd-9d4a-43ff-b106-768527572ed7.png)
# ![image.png](attachment:8fda5331-74ad-4d4e-bf5c-0936e9403481.png)

# %% [markdown]
# ![image.png](attachment:d66476b3-6e7e-4f92-8dfa-dbc41ac8e90d.png)
# ![image.png](attachment:69659a37-8bf4-498a-b722-5b0d4b798396.png)

# %% [markdown]
# ![image.png](attachment:fe34696f-1f16-4331-b6cd-c203c6a230b7.png)
# ![image.png](attachment:82151cb2-0b6d-449d-81a3-406f480f2de6.png)

# %% [markdown]
# ![image.png](attachment:6683391d-a4f6-47da-a49b-6ad27bbd84be.png)
# ![image.png](attachment:62a2369e-f1ae-449e-a246-5edcf7a823d8.png)

# %% [markdown]
# ![image.png](attachment:553a71df-8560-435a-8290-b365cd0e9712.png)
# ![image.png](attachment:af241395-3ce1-4bea-9140-a67109171919.png)

# %% [markdown]
# ![image.png](attachment:be692087-418d-4d86-af85-8a8a939f15c4.png)
# ![image.png](attachment:84a3cba5-407b-4802-af25-5eeb3edf0998.png)

# %% [markdown]
# ![image.png](attachment:6f0c0960-64f4-437d-9ff0-d4c019b5d418.png)
# ![image.png](attachment:50f1a2c2-8c48-48df-a988-b5b2f68bade4.png)

# %% [markdown]
# ![image.png](attachment:e11a8504-f35a-4c73-9810-7a69118c78d3.png)
# ![image.png](attachment:f66b2fee-1b8e-4de0-9884-abfab465271f.png)

# %% [markdown]
# ![image.png](attachment:a1655e26-7365-4948-a08d-c56bf135197a.png)
# ![image.png](attachment:8fb3d3e2-b3c7-4742-8089-c1316deff92f.png)
