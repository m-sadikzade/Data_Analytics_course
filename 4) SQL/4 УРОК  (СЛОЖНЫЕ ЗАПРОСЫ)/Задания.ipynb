# %% [markdown]
# ![image.png](attachment:89b5b991-875b-4049-84b0-94242f9fa0a4.png)
# ![image.png](attachment:7802e3d5-fb3c-4bdf-b85b-52ded2151db5.png)

# %% [markdown]
# ![image.png](attachment:7356a54a-a8b3-435d-b137-d1036e94661a.png)
# ![image.png](attachment:61f2fa25-cab3-4f98-8a97-ed818bf28a24.png)

# %% [markdown]
# ![image.png](attachment:a43618a1-dc1d-46d6-9eab-5c6662a05756.png)
# ![image.png](attachment:d398176b-6b3d-4534-a4a8-cce02cd46ad2.png)

# %% [markdown]
# ![image.png](attachment:4591a737-daa4-4217-8c63-8ce7a027bfe8.png)
# ![image.png](attachment:e85999c1-18b0-40f3-8e42-56b1f53480fe.png)

# %% [markdown]
# ![image.png](attachment:41aafae0-bf02-4dcb-bb7a-f201c239b645.png)
# ![image.png](attachment:2e9f7f84-a001-401d-9fa2-e4c8cd1797b7.png)

# %% [markdown]
# ![image.png](attachment:5ceba83f-3d4e-464c-9032-eecc0dbd6451.png)
# ![image.png](attachment:5e70688d-3775-4f9f-b89d-231f5e65a726.png)

# %% [markdown]
# ![image.png](attachment:52b54734-3d09-4d9d-ab31-241049321b62.png)
# ![image.png](attachment:7d64a561-53bd-4247-adab-24f5b704d00e.png)

# %% [markdown]
# ![image.png](attachment:a239924a-3e11-4109-be6f-5606027bc7c4.png)
# ![image.png](attachment:690b562b-62cf-44d4-8b76-144f8ffb7d32.png)

# %% [markdown]
# ![image.png](attachment:81ed271e-b799-4c49-87c6-5ab3c1d06df2.png)
# ![image.png](attachment:56fc1c7a-f9cf-4132-b92c-e438c42f0623.png)

# %% [markdown]
# ![image.png](attachment:34b6d315-bae3-44f6-922f-345496019c23.png)
# ![image.png](attachment:e0eec357-2bf7-416c-b8dc-f2ec2df89dab.png)
