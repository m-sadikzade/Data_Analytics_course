# %% [markdown]
# ![image.png](attachment:9bd4d216-9e3a-4f0f-b7b0-bc95e722fc48.png)

# %% [markdown]
# ![image.png](attachment:28987dbe-74ea-46e6-bc75-1535da2e3793.png)

# %% [markdown]
# ![image.png](attachment:d16cafa1-9a0e-47c2-8fec-3ba6da6b6c98.png)

# %% [markdown]
# ![image.png](attachment:fc4eba3d-fcf8-417b-b4f4-4ac52004e64f.png)

# %% [markdown]
# ![image.png](attachment:cb02e826-7815-4c14-9d69-014c5721bdc8.png)

# %% [markdown]
# ![image.png](attachment:44dba91e-e277-4bda-adef-597a69840d1b.png)

# %% [markdown]
# ![image.png](attachment:8326263c-f132-4c7f-9b66-45b78480715d.png)

# %% [markdown]
# ![image.png](attachment:ef4d5760-6007-4bd5-a82d-897b09e87a07.png)

# %% [markdown]
# ![image.png](attachment:8eb185ec-3bdb-45dd-93c0-4a565e62e1f3.png)

# %% [markdown]
# ![image.png](attachment:a965f68a-26bd-4410-9098-e3367c137f21.png)
