# %% [markdown]
# ![image.png](attachment:7f273fbb-6d84-44b9-9ad9-291809e74f0e.png)

# %% [markdown]
# ![image.png](attachment:aeb305ef-2b64-4d45-8976-efc9f41a802d.png)

# %% [markdown]
# ![image.png](attachment:3ec98f4b-ed82-4834-9bd6-5f7113b7c0ef.png)

# %% [markdown]
# ![image.png](attachment:8d66de7b-4cb4-4a7c-8edd-883232c37814.png)

# %% [markdown]
# ![image.png](attachment:c46c8045-de48-4b06-8a86-00ddd6d5474a.png)

# %% [markdown]
# ![image.png](attachment:a9427326-2ee3-4407-a904-d79678bb99f8.png)

# %% [markdown]
# ![image.png](attachment:0dbdfeb2-d9c1-446c-9209-b99275545d22.png)

# %% [markdown]
# ![image.png](attachment:b522ec78-3483-4432-bf5b-c914fdc22658.png)

# %% [markdown]
# ![image.png](attachment:ba6a4a6d-10be-44c3-99ae-bc980f123cb4.png)

# %% [markdown]
# ![image.png](attachment:8271cb77-edde-4afd-9cd1-449d29743fc5.png)

# %% [markdown]
# ![image.png](attachment:eebb15b7-09e2-48d8-ad44-4491bc6db3fb.png)

# %% [markdown]
# ![image.png](attachment:e2fd7494-1ff8-49d3-b776-4830db09c420.png)

# %% [markdown]
# ![image.png](attachment:6b2a48ac-326f-406c-a59a-39d4ebed6055.png)

# %% [markdown]
# ![image.png](attachment:163a2822-aa3e-4472-8144-b2e383bc88a0.png)

# %% [markdown]
# ![image.png](attachment:4af5619e-0ffe-4134-96a5-2f19b5507ca6.png)
