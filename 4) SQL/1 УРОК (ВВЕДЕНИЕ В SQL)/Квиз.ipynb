# %% [markdown]
# ![image.png](attachment:acaea153-467a-4031-90cb-438dd5574301.png)

# %% [markdown]
# ![image.png](attachment:98c56a53-f422-412d-aa92-121a1c67451b.png)

# %% [markdown]
# ![image.png](attachment:2856ae53-0276-4849-a44a-9ec627c7e655.png)

# %% [markdown]
# ![image.png](attachment:e64ad56c-0207-442a-87fb-4e7445ddb07d.png)

# %% [markdown]
# ![image.png](attachment:86bf9bbc-f252-47d5-9c8e-fdd95fcd5bf4.png)

# %% [markdown]
# ![image.png](attachment:5ffbf399-bd4d-4d20-8951-c4e4088c060e.png)

# %% [markdown]
# ![image.png](attachment:9c99487b-8ece-4f3a-850c-6621a8a94c30.png)

# %% [markdown]
# ![image.png](attachment:9f52b352-3931-451c-9b52-dfbeda72c8a6.png)

# %% [markdown]
# ![image.png](attachment:5fe025e0-a6a1-460d-81a2-666788e2b148.png)

# %% [markdown]
# ![image.png](attachment:d9801532-6791-41ff-b598-4b047efe0e8c.png)
