# %% [markdown]
# ![image.png](attachment:40da9557-f19c-4db7-be93-ecb63c2d390b.png)

# %% [markdown]
# ![image.png](attachment:700add47-d890-4f10-96f5-f5cfc00b0555.png)

# %% [markdown]
# ![image.png](attachment:9dcbbacb-bb59-4cd0-ab2e-ac505033eb8d.png)

# %% [markdown]
# ![image.png](attachment:1942e649-45f6-4e67-acc2-39617c9bb00f.png)
