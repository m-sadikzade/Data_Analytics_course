# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#p1 = 0.03
#p(h1)
180/500
# Out:
# 0.36

# %%
#p2 = 0.02
#p(h2)
170/500
# Out:
# 0.34

# %%
#p3 = 0.06
#p(h3)
(500-180-170)/500
# Out:
# 0.3

# %%
0.36*0.03 + 0.34*0.02 + 0.3*0.06
# Out:
# 0.03559999999999999

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
3x #java    => 12y p(h1) = 12/17     p1 = 0.85

# %%
x = 4y #c++ => 4y  p(h2) = 4/17      p2 = 0.9

# %%
y #python   => y   p(h3) = 1/17      p3 = 0.8

# %%
12/17 * 0.85 + 4/17 * 0.9 + 1/17 * 0.8
# Out:
# 0.8588235294117648

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# p(h1) = 18/40    p1 = 0.9
# p(h2) = 8/40     p2 = 0.4
# p(h3) = 14/40    p3 = 0.7

# %%
#p(a) = 18/40*0.9 + 8/40*0.4 + 14/40*0.7 = 0.73
18/40*0.9 + 8/40*0.4 + 14/40*0.7
# Out:
# 0.73

# %%
#p(h1/a) = p(h1)*p1/p(a)
(18/40)*0.9/0.73
# Out:
# 0.5547945205479452

# %%
#p(h2/a) = p(h2)*p2/p(a)
(8/40)*0.4/0.73
# Out:
# 0.10958904109589043

# %%
#p(h3/a) = p(h3)*p3/p(a)
(14/40)*0.7/0.73
# Out:
# 0.33561643835616434

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Три кубика        p(h1) = 3/4
#Четвёртый кубик   p(h2) = 1/4

#p(h2/a) = p(h2) * p(a/h2) / p(a)

#Вероятность выпадания белой грани  p1 = 10 / 24
#Вероятность выпадания чёрной грани p2 = 14 / 24

#полная вероятность:
from scipy import special as sp
a = (1/6 * (5/6)**6 * sp.comb(7, 1))*1/4 + (3/6 * (3/6)**6 * sp.comb(7, 1))*3/4
a
# Out:
# 0.1386942015317787

# %%
#p(h2/a) = p(h2) * p(a/h2) / p(a)
#p(h2)   = 1/4
#p(a/h2) = 1/6 (вероятность выпадения белой стороны про том, что выбран четвёртый кубик)
p2 = 1/6 * (5/6)**6 * sp.comb(7, 1)
#p(a)    = 0.11491786850387237

(1/4) * p2 / a
# Out:
# 0.7042729649328406

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
12/50 * 0.9 + 20/50*0.6 + 18/50*0.9
# Out:
# 0.78

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = 0.6*0.99 + 0.4*0.01
A
# Out:
# 0.598

# %%
0.6*0.99/0.598
# Out:
# 0.9933110367892977

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = 0.2*0.02+0.5*0.01+0.3*0.03
A
# Out:
# 0.018000000000000002

# %%
0.5*0.01/A
# Out:
# 0.27777777777777773

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
0.07 *0.02 / (0.07*0.02 + 0.93*0.95)
# Out:
# 0.001582099672279354

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
0.07 * 0.98 / (0.07 * 0.98 + 0.93 * 0.05 )
# Out:
# 0.5960034752389227

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
0.8*0.04/(0.8*0.04 + 0.15*0.06 + 0.05*0.09)
# Out:
# 0.7032967032967034
