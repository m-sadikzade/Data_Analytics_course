# %% [markdown]
# ![image.png](attachment:0fe7d929-ce1c-4359-a961-97dd60b967bc.png)

# %%
(0.5 * 0.2) + (0.5 * 0.8) #первый попал и второй не попал или первый не попал и второй попал
# Out:
# 0.5

# %% [markdown]
# ![image.png](attachment:0bed3c53-98ba-4ce4-90c1-98007af55a80.png)

# %%
#Полная вероятность = 1
0.2 * 0.3 * 0.4 #Вероятность, что никто не сдаст
# Out:
# 0.024

# %%
1-0.024 #Вероятность, что хотя бы один сдаст
# Out:
# 0.976

# %% [markdown]
# ![image.png](attachment:5a1a72ce-7b42-421b-9940-734336921dc4.png)

# %%
4/14 * 9/14
# Out:
# 0.18367346938775508

# %% [markdown]
# ![image.png](attachment:b163c211-1472-48fe-a056-3f45042d4243.png)

# %%
# x^4 = 0,0016 не попал четыре раза
x = 0.2 #не попал один раз
1-x #попал 1 раз
# Out:
# 0.8

# %% [markdown]
# ![image.png](attachment:f488fd44-0168-419b-8ad0-5048274f7708.png)

# %% [markdown]
# ![image.png](attachment:06865237-773e-48c6-b104-bb4cf68240ae.png)

# %%
3/10 * 2/9 * 1/8
# Out:
# 0.008333333333333333

# %% [markdown]
# ![image.png](attachment:2d82b0c0-f9a2-4253-9f6d-c9ccf98654a0.png)

# %% [markdown]
# ![image.png](attachment:735cd2b3-bdb4-4a4e-b86e-1c751a1cd735.png)

# %%
2/8
# Out:
# 0.25

# %% [markdown]
# ![image.png](attachment:2cde2f8a-df05-4919-a7cf-bb175322cef5.png)

# %% [markdown]
# ![image.png](attachment:951d9c79-fb7b-4ec4-93a4-06ef5caa37ff.png)

# %%
19/36
# Out:
# 0.5277777777777778
